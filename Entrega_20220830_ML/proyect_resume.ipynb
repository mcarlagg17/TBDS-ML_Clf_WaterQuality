# %% [markdown]
# # **Predicción CALIDAD del AGUA**
# ![img](https://agqlabs.es/tienda/wp-content/uploads/2020/09/análisis-calidad-del-agua.jpg)
# ## *ÍNDICE:*
# ---
# - [ 0. INTRODUCCIÓN](#0)
# - [ 1. ANÁLISIS EXPLORATORIO DE DATOS (EDA):](#1)
#     - [1.1. Acondicionamiento bases de datos](#12)
#     - [1.2. Análisis visual](#13)
#     - [1.3. Análisis estadístico](#14)
# - [ 2. MACHINE LEARNING](#2)
#     - [2.1. Preparación y limpieza de datos](#21)
#     - [2.2. Feature Engineering](#22)
#     - [2.3. Modelado](#23)
# - [ 3. RESULTADOS](#3)
#     - [3.1. Visualización y reporting de los resultados](#31)
#     - [3.2. Creación de un pipeline para el flujo automatizado](#32)
# ---
# ### *Contacto:*
# ___
# * Email: ***carla.glezz@gmail.com***
# * Linkedin: ***https://www.linkedin.com/in/mariacarlagonzalezgonzalez/***
# ---
# ---

# %% [markdown]
# # **0. Introducción**<a id='0'></a>

# %%
import pandas as pd
import os

# %% [markdown]
# Se realiza la introducción en el archivo: <a href='src/0_Introduccion.ipynb'>Intro</a>

# %% [markdown]
# # **1. Análisis exploratorio de datos**<a id='1'></a>

# %% [markdown]
# Se realiza un análisis exploratorio de los datos en el archivo: <a href='src/1_EDA.ipynb'>EDA</a>

# %% [markdown]
# # **2. Machine Learning**<a id='2'></a>

# %% [markdown]
# En el notebook de <a href='src/2a_ML_Baseline.ipynb'>Machine Learning (baseline)</a> se realiza:
#
# - Prueba de contacto con los distintos modelos supervisados de clasificación y el dataset sin tratar. (<a href='src/model/model_metrics/baseline_metrics.csv'>Métricas obtenidas de los modelos baseline</a>)
#
# - Se ajustan los hiperparámetros de todos los modelos de clasificación.
#     - Se guardan los modelos con los mejores hiperparámetros propuestos.
#     - Se obtienen las métricas de los modelos y se asocia cada uno con su path del modelo.pkl
#     (<a href='src/model/model_metrics/metrics.csv'>Métricas obtenidas de los modelos ajustados</a>)

# %%
pd.read_csv(os.getcwd()+'/src/model/model_metrics/baseline_metrics.csv',sep=';').sort_values('Precision',ascending=False)
# Out:
#                          model       ACC  Precision    Recall        F1  \
# 5            BaggingClassifier  0.968750   0.909091  0.778443  0.838710
# 9                XGBClassifier  0.973750   0.903226  0.838323  0.869565
# 4       RandomForestClassifier  0.961250   0.894737  0.712575  0.793333
# 7   GradientBoostingClassifier  0.965000   0.888112  0.760479  0.819355
# 10            VotingClassifier  0.957500   0.877863  0.688623  0.771812
# 6           AdaBoostClassifier  0.942500   0.804878  0.592814  0.682759
# 2       DecisionTreeClassifier  0.959375   0.786517  0.838323  0.811594
# 0           LogisticRegression  0.908750   0.632911  0.299401  0.406504
# 11  LinearDiscriminantAnalysis  0.903125   0.546154  0.425150  0.478114
# 3          ExtraTreeClassifier  0.897500   0.508571  0.532934  0.520468
# 1         KNeighborsClassifier  0.889375   0.419355  0.155689  0.227074
# 8                          SVC  0.895625   0.000000  0.000000  0.000000
#
#          ROC   Jaccard
# 5   0.884686  0.722222
# 9   0.913928  0.769231
# 4   0.851403  0.657459
# 7   0.874657  0.693989
# 10  0.838729  0.628415
# 6   0.788033  0.518325
# 2   0.905903  0.682927
# 0   0.639582  0.255102
# 11  0.691989  0.314159
# 3   0.736460  0.351779
# 1   0.565283  0.128079
# 8   0.500000  0.000000

# %%
pd.read_csv(os.getcwd()+'/src/model/model_metrics/metrics.csv',sep=';').sort_values('Precision',ascending=False)
# Out:
#                          model  \
# 11  GradientBoostingClassifier
# 10               XGBClassifier
# 6            BaggingClassifier
# 8   GradientBoostingClassifier
# 4       RandomForestClassifier
# 7           AdaBoostClassifier
# 1         KNeighborsClassifier
# 5            BaggingClassifier
# 2       DecisionTreeClassifier
# 9                          SVC
# 3          ExtraTreeClassifier
# 0           LogisticRegression
#
#                                          params_tried  \
# 11  {'loss': ['log_loss'], 'n_estimators': [100, 2...
# 10  {'nthread': [4], 'objective': ['binary:logisti...
# 6   {'n_estimators': [10, 20, 30, 50, 100], 'max_s...
# 8   {'n_estimators': [10, 20, 30, 50, 100], 'max_d...
# 4   {'n_estimators': array([ 10,  25,  41,  56,  7...
# 7             {'n_estimators': [10, 20, 30, 50, 100]}
# 1   {'n_neighbors': [3, 5, 7, 9, 11, 13, 15], 'wei...
# 5   {'base_estimator': [DecisionTreeClassifier(cla...
# 2   {'criterion': ['log_loss', 'gini', 'entropy'],...
# 9   [{'C': [1, 10, 100, 1000], 'kernel': ['linear'...
# 3   {'criterion': ['gini', 'entropy'], 'max_depth'...
# 0   {'penalty': ['l1', 'l2', 'elasticnet', 'none']...
#
#                                           best_params       ACC  Precision  \
# 11  {'learning_rate': 0.01, 'loss': 'log_loss', 'm...  0.920000   0.975610
# 10  {'colsample_bytree': 0.7, 'learning_rate': 0.0...  0.973750   0.937063
# 6           {'max_samples': 0.5, 'n_estimators': 100}  0.967500   0.919708
# 8   {'criterion': 'mse', 'loss': 'exponential', 'm...  0.972500   0.918367
# 4   {'class_weight': None, 'criterion': 'entropy',...  0.972500   0.912752
# 7                               {'n_estimators': 100}  0.939375   0.777778
# 1   {'algorithm': 'ball_tree', 'leaf_size': 20, 'n...  0.899375   0.615385
# 5   {'base_estimator': DecisionTreeClassifier(clas...  0.916250   0.562738
# 2   {'class_weight': 'balanced', 'criterion': 'gin...  0.912500   0.554217
# 9   {'C': 1000, 'class_weight': 'balanced', 'kerne...  0.870625   0.438650
# 3   {'class_weight': 'balanced', 'criterion': 'gin...  0.836875   0.385366
# 0   {'class_weight': 'balanced', 'max_iter': 50, '...  0.795625   0.304878
#
#       Recall        F1       ROC   Jaccard  \
# 11  0.239521  0.384615  0.619412  0.238095
# 10  0.802395  0.864516  0.898057  0.761364
# 6   0.754491  0.828947  0.873407  0.707865
# 8   0.808383  0.859873  0.900005  0.754190
# 4   0.814371  0.860759  0.902650  0.755556
# 7   0.586826  0.668942  0.783643  0.502564
# 1   0.095808  0.165803  0.544415  0.090395
# 5   0.886228  0.688372  0.902988  0.524823
# 2   0.826347  0.663462  0.874444  0.496403
# 9   0.856287  0.580122  0.864292  0.408571
# 3   0.946108  0.547660  0.885126  0.377088
# 0   0.748503  0.433276  0.774810  0.276549
#
#                                 model_path
# 11  model/GradientBoostingClassifier_1.pkl
# 10                 model/XGBClassifier.pkl
# 6            model/BaggingClassifier_1.pkl
# 8     model/GradientBoostingClassifier.pkl
# 4         model/RandomForestClassifier.pkl
# 7             model/AdaBoostClassifier.pkl
# 1           model/KNeighborsClassifier.pkl
# 5              model/BaggingClassifier.pkl
# 2         model/DecisionTreeClassifier.pkl
# 9                            model/SVC.pkl
# 3            model/ExtraTreeClassifier.pkl
# 0           model/LogisticRegression_1.pkl

# %% [markdown]
# En el notebook de <a href='src/2b_ML_BalancedData.ipynb'>Machine Learning</a> se realiza:
#
# - Feature selection con ***RFE***. (<a href='src/data/processed/data_featureselected.csv'>Métricas de los modelos con las features reducidas</a>)
#
# - Balanceo de los datos:
#
#     - Método oversampling: ***SMOTE***
#
#     - Método mixto: ***SMOTEENN***
#
# - Modelado con los estimadores cuyas métricas resultan más satisfactorias:
#
#     - Baseline con el nuevo dataset
#
#     - Modelado modificando hiperparámetros con el nuevo dataset
#
#     - Modelado con todos las features añadiendo el balanceo y ajuste de parámetros
#
# - Adicionalmente, se prueba el modelo de red neuronal ***Perceptrón***. (<a href='src/model/model_metrics/DL_metrics.csv'>Métricas del Perceptrón</a>)

# %%
pd.read_csv(os.getcwd()+'/src/model/model_metrics/baseline_fs_metrics.csv',sep=';').sort_values('Precision',ascending=False)
# Out:
#                          model       ACC  Precision    Recall        F1  \
# 4       RandomForestClassifier  0.958750   0.917355  0.664671  0.770833
# 9                XGBClassifier  0.962500   0.902256  0.718563  0.800000
# 10            VotingClassifier  0.957500   0.896000  0.670659  0.767123
# 5            BaggingClassifier  0.952500   0.858268  0.652695  0.741497
# 7   GradientBoostingClassifier  0.951875   0.846154  0.658683  0.740741
# 6           AdaBoostClassifier  0.930625   0.750000  0.502994  0.602151
# 0           LogisticRegression  0.903125   0.625000  0.179641  0.279070
# 2       DecisionTreeClassifier  0.924375   0.618557  0.718563  0.664820
# 11  LinearDiscriminantAnalysis  0.891250   0.472000  0.353293  0.404110
# 3          ExtraTreeClassifier  0.885625   0.457895  0.520958  0.487395
# 1         KNeighborsClassifier  0.885000   0.373134  0.149701  0.213675
# 8                          SVC  0.895625   0.000000  0.000000  0.000000
#
#          ROC   Jaccard
# 4   0.828846  0.627119
# 9   0.854745  0.666667
# 10  0.830793  0.622222
# 5   0.820067  0.589189
# 7   0.822363  0.588235
# 6   0.741727  0.430769
# 0   0.583540  0.162162
# 2   0.833461  0.497925
# 11  0.653618  0.253219
# 3   0.724540  0.322222
# 1   0.560196  0.119617
# 8   0.500000  0.000000

# %%
pd.read_csv(os.getcwd()+'/src/model/model_metrics/fs_metrics.csv',sep=';').sort_values('Precision',ascending=False)
# Out:
#                         model  \
# 0      RandomForestClassifier
# 1           BaggingClassifier
# 2               XGBClassifier
# 3  GradientBoostingClassifier
#
#                                         params_tried  \
# 0  {'n_estimators': array([ 10,  25,  41,  56,  7...
# 1  {'n_estimators': [10, 20, 30, 50, 100], 'max_s...
# 2  {'nthread': [4], 'objective': ['binary:logisti...
# 3  {'n_estimators': [10, 20, 30, 50, 100], 'max_d...
#
#                                          best_params       ACC  Precision  \
# 0  {'class_weight': None, 'criterion': 'entropy',...  0.957500   0.915966
# 1          {'max_samples': 0.5, 'n_estimators': 100}  0.956875   0.908333
# 2  {'colsample_bytree': 1.0, 'learning_rate': 0.0...  0.955000   0.880000
# 3  {'criterion': 'mse', 'loss': 'log_loss', 'max_...  0.953125   0.848485
#
#      Recall        F1       ROC   Jaccard  \
# 0  0.652695  0.762238  0.822858  0.615819
# 1  0.652695  0.759582  0.822509  0.612360
# 2  0.658683  0.753425  0.824108  0.604396
# 3  0.670659  0.749164  0.828351  0.598930
#
#                                model_path
# 0      model/RandomForestClassifier_1.pkl
# 1           model/BaggingClassifier_2.pkl
# 2               model/XGBClassifier_1.pkl
# 3  model/GradientBoostingClassifier_2.pkl

# %%
pd.read_csv(os.getcwd()+'/src/model/model_metrics/metrics_balanced.csv',sep=';').sort_values('Precision',ascending=False)
# Out:
#                         model  \
# 3  GradientBoostingClassifier
# 1      RandomForestClassifier
# 0               XGBClassifier
# 2           BaggingClassifier
#
#                                         params_tried  \
# 3  [{'n_estimators': [10, 20, 30, 50, 100], 'max_...
# 1  {'n_estimators': array([ 10,  25,  41,  56,  7...
# 0  {'nthread': [4], 'objective': ['binary:logisti...
# 2  {'n_estimators': [10, 20, 30, 50, 100], 'max_s...
#
#                                          best_params       ACC  Precision  \
# 3  {'learning_rate': 0.1, 'loss': 'log_loss', 'ma...  0.941875   0.654167
# 1  {'class_weight': 'balanced', 'criterion': 'ent...  0.938750   0.638554
# 0  {'colsample_bytree': 0.6, 'learning_rate': 0.0...  0.927500   0.593407
# 2          {'max_samples': 0.5, 'n_estimators': 100}  0.921875   0.575000
#
#      Recall        F1       ROC   Jaccard  \
# 3  0.940120  0.771499  0.941100  0.628000
# 1  0.952096  0.764423  0.944645  0.618677
# 0  0.970060  0.736364  0.946300  0.582734
# 2  0.964072  0.720358  0.940515  0.562937
#
#                                model_path
# 3  model/GradientBoostingClassifier_3.pkl
# 1      model/RandomForestClassifier_2.pkl
# 0               model/XGBClassifier_2.pkl
# 2           model/BaggingClassifier_3.pkl

# %%
pd.read_csv(os.getcwd()+'/src/model/model_metrics/DL_metrics.csv',sep=';').sort_values('Precision',ascending=False)
# Out:
#            model       ACC  Precision    Recall        F1       ROC   Jaccard
# 0  MLPClassifier  0.946875   0.788732  0.670659  0.724919  0.824862  0.568528
# 1  MLPClassifier  0.920000   0.719101  0.383234  0.500000  0.682894  0.333333

# %%
pd.read_csv(os.getcwd()+'/src/model/model_metrics/DL_metrics_hyp.csv',sep=';').sort_values('Precision',ascending=False)
# Out:
#            model                                       params_tried  \
# 1  MLPClassifier  {'activation': ['relu', 'logistic'], 'early_st...
# 2  MLPClassifier  {'activation': ['relu', 'logistic'], 'early_st...
# 0  MLPClassifier  {'activation': ['relu'], 'early_stopping': [Tr...
#
#                                          best_params       ACC  Precision  \
# 1  {'activation': 'relu', 'early_stopping': True,...  0.936875   0.858696
# 2  {'activation': 'relu', 'early_stopping': True,...  0.940000   0.784000
# 0  {'activation': 'relu', 'early_stopping': True,...  0.933750   0.760684
#
#      Recall        F1       ROC   Jaccard                 model_path
# 1  0.473054  0.610039  0.731991  0.438889    model/MLPClassifier.pkl
# 2  0.586826  0.671233  0.783992  0.505155  model/MLPClassifier_2.pkl
# 0  0.532934  0.626761  0.756697  0.456410  model/MLPClassifier_1.pkl

# %% [markdown]
# # **3. Resultados y conclusiones**<a id='3'></a>

# %% [markdown]
# En el notebook de <a href='src/3_Resultados.ipynb'>Resultados</a> se realiza:
#
# - Visualización de los distintos resultados de los modelos
# - Elección del modelo, según sus métricas
#
# El modelo seleccionado es el `GradientBoostClassifier()`
